# %% [markdown]
# <a href="https://colab.research.google.com/github/francesr1001/DSC1107_FA1/blob/main/FA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Frances Aneth Rosales**
#
# **FA1 DATA MINING AND WRANGLING**

# %% [markdown]
# *   **Lecture 2. Data Visualization (Programming)**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
diamonds_path = '/content/drive/MyDrive/DATA MINING/diamonds.csv'
import pandas as pd
diamonds = pd.read_csv(diamonds_path)
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
from matplotlib import pyplot as plt
_df_91['depth'].plot(kind='line', figsize=(8, 4), title='depth')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_56.groupby('clarity').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Discrete variables
sns.countplot(x='cut', data=diamonds)
plt.title('Discrete variables')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(diamonds['carat'], bins=30, kde=False, color='skyblue')

plt.xlabel('Carat')
plt.ylabel('Frequency')
plt.title('Histogram of Carat in Diamonds')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.histplot(diamonds['carat'], bins=range(0, 4, 1), kde=False, color='skyblue')

plt.xlabel('Carat')
plt.ylabel('Frequency')
plt.title('Histogram of Carat in Diamonds')

plt.xlim(0, 3)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(x='cut', y='clarity', data=diamonds, size='cut', sizes=(50, 200), palette='viridis')

plt.xlabel('Cut')
plt.ylabel('Clarity')
plt.title('Discrete versus discrete \n Scatter Plot of Cut vs Clarity in Diamonds  ')

plt.show()
# Out:
# <ipython-input-29-45eb183ebb29>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='cut', y='clarity', data=diamonds, size='cut', sizes=(50, 200), palette='viridis')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a boxplot
plt.figure(figsize=(10, 8))
sns.boxplot(x='cut', y='price', data=diamonds)

# Set plot labels and title
plt.xlabel('Cut')
plt.ylabel('Price')
plt.title('Boxplot of Price by Cut')

# Show the plot
plt.show()

# %% [markdown]
# *   **Lecture 3. Data Transformation (Programming)**

# %%
diamonds['price_per_carat'] = diamonds['price'] / diamonds['carat']

print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_per_carat
# 0      1417.391304
# 1      1552.380952
# 2      1421.739130
# 3      1151.724138
# 4      1080.645161

# %%
missing_values = diamonds.isnull().sum()
print(missing_values)
# Out:
# carat              0
# cut                0
# color              0
# clarity            0
# depth              0
# table              0
# price              0
# x                  0
# y                  0
# z                  0
# price_per_carat    0
# dtype: int64

# %%
print('Isolating data \n filter()')
filtered_data = diamonds[diamonds['price'] >= 10000]

print(filtered_data)
# Out:
# Isolating data
#  filter()
#        carat        cut color clarity  depth  table  price     x     y     z
# 21927   1.51       Good     H     VS2   64.0   59.0  10000  7.25  7.19  4.62
# 21928   1.70      Ideal     J     VS2   60.5   58.0  10002  7.73  7.74  4.68
# 21929   1.03      Ideal     E    VVS2   60.6   59.0  10003  6.50  6.53  3.95
# 21930   1.23  Very Good     G    VVS2   60.6   55.0  10004  6.93  7.02  4.23
# 21931   1.25      Ideal     F     VS2   61.6   55.0  10006  6.93  6.96  4.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
# ...

# %%
filtered_data = diamonds[(diamonds['price'] >= 10000) & (diamonds['clarity'].isin(['VVS1', 'IF']))]

print(filtered_data)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 21946   1.01  Very Good     F    VVS1   62.9   57.0  10019  6.35  6.41  4.01
# 21959   1.02  Very Good     E      IF   61.7   60.0  10029  6.38  6.52  3.98
# 21961   1.03  Very Good     F      IF   62.8   57.0  10032  6.40  6.47  4.04
# 21978   1.00  Very Good     F      IF   63.2   63.0  10046  6.26  6.24  3.95
# 21986   1.11      Ideal     G      IF   61.2   54.0  10053  6.71  6.73  4.11
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27650   2.29    Premium     J      IF   61.4   60.0  18594  8.49  8.45  5.20
# 27671   1.42      Ideal     F    VVS1   60.8   56.0  18682  7.25  7.32  4.43
# 27677   1.28      Ideal     E      IF   60.7   57.0  18700  7.09  6.99  4.27
# 27733   1.51  Very Good     F    VVS1   62.6   59.0  18777  7.33  7.24  4.56
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
#
# [415 rows x 10 columns]

# %%
selected_columns = diamonds[['carat', 'cut', 'color', 'clarity']]

print(selected_columns)
# Out:
#        carat        cut color clarity
# 0       0.23      Ideal     E     SI2
# 1       0.21    Premium     E     SI1
# 2       0.23       Good     E     VS1
# 3       0.29    Premium     I     VS2
# 4       0.31       Good     J     SI2
# ...      ...        ...   ...     ...
# 53935   0.72      Ideal     D     SI1
# 53936   0.72       Good     D     SI1
# 53937   0.70  Very Good     D     SI1
# 53938   0.86    Premium     H     SI2
# 53939   0.75      Ideal     D     SI2
#
# [53940 rows x 4 columns]

# %% [markdown]
# ***Lecture 4. Data Wrangling (Programming)***

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/DATA MINING/heights.csv"

heights = pd.read_csv(file_path)

print(heights.head())
# Out:
#     earn  height     sex  ed  age   race
# 0  50000    74.4    male  16   45  white
# 1  60000    65.5  female  16   58  white
# 2  30000    63.6  female  16   29  white
# 3  50000    63.1  female  16   91  other
# 4  51000    63.4  female  17   39  white

# %%
heights
# Out:
#     earn  height     sex  ed  age   race
# 0  50000    74.4    male  16   45  white
# 1  60000    65.5  female  16   58  white
# 2  30000    63.6  female  16   29  white
# 3  50000    63.1  female  16   91  other
# 4  51000    63.4  female  17   39  white
# 5  90000    64.4  female  15   26  white

# %%
average_height = heights['age'].mean()
print("Average age of adults:", average_height)
# Out:
# Average age of adults: 48.0

# %%
heights_sorted = heights.sort_values(by='age', ascending=False)
heights_sorted
# Out:
#     earn  height     sex  ed  age   race
# 3  50000    63.1  female  16   91  other
# 1  60000    65.5  female  16   58  white
# 0  50000    74.4    male  16   45  white
# 4  51000    63.4  female  17   39  white
# 2  30000    63.6  female  16   29  white
# 5  90000    64.4  female  15   26  white

# %%
import pandas as pd

table4a_long = pd.melt(heights, id_vars=['earn'], value_vars=['ed', 'age'], var_name='number', value_name='old')
table4a_long
# Out:
#      earn number  old
# 0   50000     ed   16
# 1   60000     ed   16
# 2   30000     ed   16
# 3   50000     ed   16
# 4   51000     ed   17
# 5   90000     ed   15
# 6   50000    age   45
# 7   60000    age   58
# 8   30000    age   29
# 9   50000    age   91
# 10  51000    age   39
# 11  90000    age   26
